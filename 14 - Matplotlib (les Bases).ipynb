# %% [markdown]
# <a href="https://colab.research.google.com/github/MachineLearnia/Python-Machine-Learning/blob/master/14%20-%20Matplotlib%20(les%20Bases).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 14/30 Matplotlib : Graphiques de Base

# %% [markdown]
# ## 1. Pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Graphiques simples

# %%
X = np.linspace(0, 2, 10)
y = X**2

plt.plot(X, y)
plt.show()

# %%
plt.scatter(X, y)
plt.show()

# %% [markdown]
# ### Styles Graphiques
# Il existe beaucoup de styles a ajouter aux graphiques. Voici les plus importants a retenir :
# - **c** : couleur de la ligne
# - **lw** : epaisseur de la ligne (pour les graphiques plot)
# - **ls** : style de la ligne (pour les graphiques plot)
# - **size** : taille du point (pour les graphiques scatter)
# - **marker** : style de points (pour les graphiques scatter)
# - **alpha** : transparence du graphique

# %%
plt.plot(X, y, c='red', lw=4, ls='--', alpha=0.8)
plt.show()

# %% [markdown]
# ## 2. Cycle de vie d'une figure
# Pour créer des figures proprements, on doit suivre le cycle de vie suivant :
# 1. **plt.figure**(figsize())
# 2. **plt.plot()**
# 3. Extras (titre, axes, legendes)
# 4. **plt.show()**

# %%
X = np.linspace(0, 2, 10)

plt.figure() # Création d'une figure
plt.plot(X, X**2, label='quadratique') # premiere courbe
plt.plot(X, X**3, label='cubique') # deuxieme courbe
# Extra information
plt.title('figure 1') # titre
plt.xlabel('axe x') # axes
plt.ylabel('axe y') # axes
plt.legend() # legend

plt.savefig('figure.png') # sauvegarde la figure dans le repertoire de travail
plt.show() # affiche la figure

# %% [markdown]
# ## 3. Subplots
# Les subplots sont un autre éléments a ajouter pour créer plusieurs graphiques sur une meme figure

# %%
plt.subplot(2, 1, 1)
plt.plot(x, y, c='red')
plt.subplot(2, 1, 2)
plt.plot(x, y, c='blue')

# %% [markdown]
# ## 4. Méthode orientée objet

# %%
fig, ax = plt.subplots(2, 1, sharex=True) # partage le meme axe pour les subplots
ax[0].plot(x, y)
ax[1].plot(x, np.sin(x))
plt.show()

# %% [markdown]
# ## 5. Exercice et Solution
# Créez une fonction "graphique" qui permet de tracer sur une seule et meme figure une série de graphiques issue d'un dictionnaire contenant plusieurs datasets :

# %%
def graphique(dataset):
  # Votre code ici...
  return

# Voici le dataset utilisé
dataset = {f"experience{i}": np.random.randn(100) for i in range(4)}

dataset
# Out:
# {'experience0': array([ 0.92804844,  0.33516898,  0.55309709, -1.07573199, -1.07624538,
#         -0.81482657,  0.15114633,  0.63747935,  0.18806535, -1.71042743,
#         -0.20278445, -0.10054101,  1.05304799, -0.19912171, -0.77857624,
#          0.73269034,  0.88875196, -0.12009552,  1.80957285,  0.12365667,
#          0.6953499 , -0.63144816,  0.80405614, -1.27365735,  0.11486195,
#          0.03634687,  0.2421594 , -0.79008759, -1.30848695,  0.33686625,
#         -0.98044402,  1.35223002, -0.82131056, -0.70128586,  1.13780765,
#          0.04146608,  0.22854191, -1.32236638, -0.80526202, -0.62017993,
#         -1.89193359,  0.65580725,  0.78497084, -2.27713804,  0.95771377,
#         -0.14698355,  0.27781866, -0.74993233,  0.51968001,  1.63176092,
#         -0.29792913, -0.70744897,  1.4509717 , -2.52203254,  0.18812063,
#         -0.6047979 ,  0.85575977, -0.12140344,  1.50752995, -0.01106437,
#          0.17837986, -2.46623   ,  1.37320453, -1.49467193,  1.76262163,
#         -0.15353643, -1.05102938, -0.47996854, -2.93356438, -1.29856185,
#         -0.81818924, -0.76044761,  0.69928771,  1.69857966,  0.38555841,
#          1.61775442, -1.06241799,  1.83605863, -0.02032763, -2.15554235,
#         -0.21374026, -0.79901805, -0.08414439, -1.34714981, -0.95587371,
#          0.4853687 ,  0.915496  , -0.97296851, -0.30406011, -0.2075205 ,
#         -1.15946444,  0.09687011, -0.40446908,  0.30774657,  0.1366278 ,
#          0.9477061 , -1.28802237,  2.04397308, -1.86249807,  1.05477469,
#         -0.32634899,  2.36802755,  2.00974971,  0.84138175, -1.5683616 ,
#          0.26405607,  0.6574256 , -0.44200214,  0.53291985, -0.48368434]),
#  'experience3': array([-0.45978999, -1.18266162,  0.54826435,  0.74107286, -0.94224475,
#          0.98175679, -0.58158806,  0.72677148,  0.68055519, -0.97705821,
#         -0.0514621 ,  0.35899771, -0.51572544,  0.20405679, -0.37537773,
#          0.25899123,  1.02671086,  0.44871002, -0.74976132,  0.70514745,
#          0.46781029, -0.4686509 , -0.47591656,  0.14211645,  1.17694432,
#         -0.03173514, -0.35894168,  0.95674863, -0.45404054, -2.2893221 ,
#          0.67228449,  0.20893785,  0.8195046 ,  1.12739157,  2.30123482,
#          0.88850872,  0.58675404,  0.6888698 , -0.29919914,  0.94375306,
#         -1.33469342, -0.28308768, -0.82981305,  0.51892332, -0.72084188,
#          0.5338685 , -0.87429619, -0.42100704, -0.5361802 , -0.26213308,
#          0.40798706,  0.00351819, -0.63440334, -0.09787611,  0.39795598,
#         -2.11094566,  0.13543536,  2.25111598,  0.10184502, -0.11220779,
#         -1.50481106, -2.31171774, -0.54716546, -0.16840759,  0.73383357,
#          1.04222232, -0.35337975, -0.31868736,  0.78956437, -1.87102844,
#         -0.47750567,  1.67454469, -0.85859759, -1.19665698, -0.59040696,
#          0.4987462 ,  0.41177052, -1.88425789, -1.08705165,  0.50663704,
#          0.31684096, -0.41361586,  0.01443578,  1.53268325, -1.67367438,
#          0.22563225, -0.06465087,  0.85428292,  2.04967192,  0.62332329,
#         -1.44290176, -0.60122062,  1.281793  ,  0.17209418,  0.0666515 ,
#         -0.77830968, -1.14022022, -0.24478686,  0.31583736,  0.89940075])}

# %%
# SOLUTION
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12, 20))
    
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k])
        plt.title(k)
        
    plt.show()

# %%
graphique(dataset)
